# %%
#ASTC



import time
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

import pandas as pd

driver = webdriver.Chrome()
driver.maximize_window()

link = 'https://www.redbus.in/online-booking/astc/'
driver.get(link)

wait = WebDriverWait(driver, 20)

routelist = []
routelinklist = []

scrolling = True
while scrolling:
    old_page_source = driver.page_source

    body = driver.find_element(By.TAG_NAME, "body")
    body.send_keys(Keys.PAGE_DOWN)

    time.sleep(2)

    new_page_source = driver.page_source

    if new_page_source == old_page_source:
        scrolling = False

for page_number in range(1, 5):
    try:
        routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, 'route')))
        
        for route in routes:
            route_text = route.text
            route_link = route.get_attribute('href')
            routelist.append(route_text)
            routelinklist.append(route_link)

        if page_number < 4:
            time.sleep(2)
            next_page_xpath = f'//div[contains(@class,"DC_117_pageTabs") and text()="{page_number + 1}"]'
            
            next_page = wait.until(EC.element_to_be_clickable((By.XPATH, next_page_xpath)))
            time.sleep(5)
            
            driver.execute_script("arguments[0].scrollIntoView(true);", next_page)
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
    finally:
        print(f"Processed page {page_number}")

route_data = {'Route': routelist, 'Link': routelinklist}
df_routes = pd.DataFrame(route_data)
df_routes.index = df_routes.index + 1
df_routes.to_csv('ASTC_data.csv', index=False)

driver.quit()

import time
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome()
driver.minimize_window()
master_df = pd.DataFrame()

for link, routename in zip(routelinklist, routelist):
    driver.get(link)

    state = 'ASTC'
    statelist = []
    busroutelist = []
    busnamelist = []
    bustypelist = []
    departing_time_list = []
    duration_list = []
    reaching_time_list = []
    star_rating_list = []
    price_list = []
    seats_available_list = []

    scrolling = True
    last_height
# Out:
# Processed page 1
# Processed page 2
# Processed page 3
# Processed page 4
# Data from https://www.redbus.in/bus-tickets/tezpur-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/guwahati-to-tezpur added successfully!
# Data from https://www.redbus.in/bus-tickets/guwahati-to-nagaon added successfully!
# Data from https://www.redbus.in/bus-tickets/nagaon-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/goalpara-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/jorhat-to-north-lakhimpur added successfully!
# Data from https://www.redbus.in/bus-tickets/dhubri-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/jorhat-to-dibrugarh added successfully!
# Data from https://www.redbus.in/bus-tickets/north-lakhimpur-to-jorhat added successfully!
# Data from https://www.redbus.in/bus-tickets/north-lakhimpur-to-sibsagar added successfully!
# Data from https://www.redbus.in/bus-tickets/tezpur-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/guwahati-to-tezpur added successfully!
# Data from https://www.redbus.in/bus-tickets/guwahati-to-nagaon added successfully!
# Data from https://www.redbus.in/bus-tickets/nagaon-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/goalpara-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/jorhat-to-north-lakhimpur added successfully!
# Data from https://www.redbus.in/bus-tickets/dhubri-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/jorhat-to-dibrugarh added successfully!
# Data from https://www.redbus.in/bus-tickets/north-lakhimpur-to-jorhat added successfully!
# Data from https://www.redbus.in/bus-tickets/north-lakhimpur-to-sibsagar added successfully!
# Data from https://www.redbus.in/bus-tickets/north-lakhimpur-to-dibrugarh added successfully!
# Data from https://www.redbus.in/bus-tickets/tinsukia-to-jorhat added successfully!
# Data from https://www.redbus.in/bus-tickets/tezpur-to-north-lakhimpur added successfully!
# Data from https://www.redbus.in/bus-tickets/north-lakhimpur-to-moran added successfully!
# Data from https://www.redbus.in/bus-tickets/guwahati-to-gohpur added successfully!
# Data from https://www.redbus.in/bus-tickets/guwahati-to-kaliabor added successfully!
# Data from https://www.redbus.in/bus-tickets/guwahati-to-tumuki-tezpur-medical added successfully!
# Data from https://www.redbus.in/bus-tickets/dibrugarh-to-tezpur added successfully!
# Data from https://www.redbus.in/bus-tickets/biswanath-charali-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/dibrugarh-to-north-lakhimpur added successfully!
# Data from https://www.redbus.in/bus-tickets/moran-to-north-lakhimpur added successfully!
# Data from https://www.redbus.in/bus-tickets/tumuki-tezpur-medical-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/biswanath-charali-to-dibrugarh added successfully!
# Data from https://www.redbus.in/bus-tickets/gohpur-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/sibsagar-to-dhemaji added successfully!
# Data from https://www.redbus.in/bus-tickets/north-lakhimpur-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/haflong-to-guwahati added successfully!
# Data from https://www.redbus.in/bus-tickets/tezpur-to-moran added successfully!
# Data from https://www.redbus.in/bus-tickets/moran-to-tezpur added successfully!
# Data from https://www.redbus.in/bus-tickets/bokakhat-to-dibrugarh added successfully!
